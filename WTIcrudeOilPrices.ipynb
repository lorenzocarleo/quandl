# %%
import pandas as pd 
import numpy as np 
import quandl as quandl

# %%
quandl.ApiConfig.api_key = "xxxxxxx"

mydata = quandl.get('COM/FUELOIL')

print(mydata)
# Out:
#             Value
# Date
# 1986-06-02  0.402
# 1986-06-03  0.393
# 1986-06-04  0.378
# 1986-06-05  0.390
# 1986-06-06  0.385
# ...           ...
# 2018-08-21  2.096
# 2018-08-22  2.144
# 2018-08-23  2.149
# 2018-08-24  2.171
# 2018-08-27  2.185
#
# [8119 rows x 1 columns]

# %%
mydata = quandl.get("COM/FUELOIL", start_date="2013-12-31", end_date="2024-01-05")

# %%
mydata
# Out:
#             Value
# Date
# 2013-12-31  3.082
# 2014-01-02  3.003
# 2014-01-03  2.967
# 2014-01-06  2.972
# 2014-01-07  2.976
# ...           ...
# 2018-08-21  2.096
# 2018-08-22  2.144
# 2018-08-23  2.149
# 2018-08-24  2.171
# 2018-08-27  2.185
#
# [1180 rows x 1 columns]

# %%
oil = quandl.get('COM/FUELOIL').squeeze()
oil.plot(lw=2, title='WTI Fuel Oil price')
# Out:
# <Axes: title={'center': 'WTI Fuel Oil price'}, xlabel='Date'>
